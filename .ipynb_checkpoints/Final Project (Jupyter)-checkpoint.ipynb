# %% [markdown]
# # Olympic Odysseys: The Impact of the "Golden Goal" On The Price Of Hockey Cards
#
# Jude Yurcich
# ECO 590
# Spring 2026

# %% [markdown]
# # This notebook contains an eBay API, cleaning that API, as well as graphs
#
# # Motivation
#
# One of the most famous speculative markets outside of formalized market trading is the sports card market, and for good reason. Sports cards come in all sorts of variations and can sell for millions of dollars, demonstrating how much money is in the market. For example, a joint Kobe Bryant and Michael Jordan basketball card sold for $12.9 million in August of 2025. eBay is one of the most important platforms to buy not only trading cards, but almost anything that has value. The 2026 Winter Olympics in Milano Cortina featured an ice hockey tournament among major hockey nations, with the United States beating Canada in overtime of the final. The scorer of the "Golden Goal," Jack Hughes, is an NHL star and has many cards to his name. I am interested in seeing if the price of his cards went up after the Olympic goal that brought him even more fame.
# https://www.paulfrasercollectibles.com/blogs/most-recent/the-most-valuable-sports-trading-cards-of-all-time?srsltid=AfmBOooGrkM4DR18Z55j1RqqhnHuIAuRLrZQIpkfzT3h61T9kjnHd6A9

# %% [markdown]
# # Research Question
#
# 1. Did the 2026 Winter Olympics results cause Jack Hughes' graded hockey cards to rise in value?

# %% [markdown]
# # Part 1: eBay API

# %%
#This will import the packages that I need to do data analysis
import requests
import re
import ast
import pandas as pd
import json
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
#imports api from provider
from serpapi import EbaySearch

#These are the parameters for the API search
params = {
    "engine": "ebay",
    "_nkw": "jack hughes young guns psa 10",
    "ebay_domain": "ebay.com",
    "api_key": "12a13973b8d58a4cc7b569859b257ef029573e1b3f116a9ecfcebd95b1f016a5",
    "show_only": "Sold",
    "buying_format": "BIN",
    "lh_sold": "1",
    "_ipg": "200"
}

# This code will search within the parameters and create a variable for the results
search = EbaySearch(params)
results = search.get_dict()

# This creates a json for the results so it can be turned into a dataframe
data_json = json.dumps(results)

# This will turn the json into a dataframe
df1 = pd.DataFrame(results["organic_results"])
df1.to_csv("df1_output.csv", index=False)

# %%
# Creates "expensive" variable for cards worth more than 100 dollars
expensive = [
    item for item in results["organic_results"]
    if isinstance(item.get("price"), dict)
    and item["price"].get("extracted", 0) > 300
    and item.get("sold_date") is not None
]
# This will turn the json into a dataframe
dfE = pd.DataFrame(expensive)

# %% [markdown]
# # Part 2: Cleaning the Data

# %%
# Prints part of dataframe to see what it looks like
df1
# Out:
#                                                  title  \
# 0    2019-20 Series 1 - Jack Hughes Rookie RC YOUNG...
# 1    2019 Jack Hughes O-Pee-Chee OPC Update Retro M...
# 2       2019 Upper Deck Quinn Hughes Young Guns PSA 10
# 3    2019-20 Upper Deck - Young Guns Jack Hughes #2...
# 4    2024 Upper Deck Jack Hughes Young Guns Renewed...
# ..                                                 ...
# 235  2019-20 UD Shooting Stars Jack Hughes ROOKIE #...
# 236  JACK HUGHES 2019-20 Upper Deck Young Guns RC #...
# 237  2019-20 Upper Deck Jack Hughes Young Guns Rook...
# 238  2019-20 Upper Deck - Young Guns Jack Hughes #2...
# 239  🥇🔥Jack Hughes-2019-20 Upper Deck - Silver Foil...
#
#                                                   link  \
# 0    https://www.ebay.com/itm/389860032154?_skw=jac...
# 1    https://www.ebay.com/itm/137288306534?_skw=jac...
# 2    https://www.ebay.com/itm/157897248275?_skw=jac...
# 3    https://www.ebay.com/itm/318244628865?_skw=jac...
# 4    https://www.ebay.com/itm/127853238112?_skw=jac...
# ..                                                 ...
# 235  https://www.ebay.com/itm/404322038011?_skw=jac...
# 236  https://www.ebay.com/itm/277747402089?_skw=jac...
# 237  https://www.ebay.com/itm/236657453349?_skw=jac...
# 238  https://www.ebay.com/itm/267585635994?_skw=jac...
# 239  https://www.ebay.com/itm/317912420889?_skw=jac...
#
#                                           serpapi_link    product_id  \
# 0    https://serpapi.com/search.json?ebay_domain=eb...  389860032154
# 1    https://serpapi.com/search.json?ebay_domain=eb...  137288306534
# 2    https://serpapi.com/search.json?ebay_domain=eb...  157897248275
# 3    https://serpapi.com/search.json?ebay_domain=eb...  318244628865
# 4    https://serpapi.com/search.json?ebay_domain=eb...  127853238112
# ..                                                 ...           ...
# 235  https://serpapi.com/search.json?ebay_domain=eb...  404322038011
# 236  https://serpapi.com/search.json?ebay_domain=eb...  277747402089
# 237  https://serpapi.com/search.json?ebay_domain=eb...  236657453349
# 238  https://serpapi.com/search.json?ebay_domain=eb...  267585635994
# 239  https://serpapi.com/search.json?ebay_domain=eb...  317912420889
#
#        condition                                      price  \
# 0    New (Other)    {'raw': '$204.69', 'extracted': 204.69}
# 1    New (Other)     {'raw': '$150.00', 'extracted': 150.0}
# 2    New (Other)     {'raw': '$275.00', 'extracted': 275.0}
# 3    New (Other)     {'raw': '$130.00', 'extracted': 130.0}
# 4    New (Other)     {'raw': '$110.00', 'extracted': 110.0}
# ..           ...                                        ...
# 235  New (Other)       {'raw': '$75.00', 'extracted': 75.0}
# 236  New (Other)    {'raw': '$299.99', 'extracted': 299.99}
# 237  New (Other)     {'raw': '$318.60', 'extracted': 318.6}
# 238  New (Other)     {'raw': '$315.00', 'extracted': 315.0}
# 239  New (Other)  {'raw': '$1,400.00', 'extracted': 1400.0}
#
#                                             shipping  \
# 0    {'raw': '+$13.75 delivery', 'extracted': 13.75}
# 1      {'raw': '+$5.72 delivery', 'extracted': 5.72}
# 2       {'raw': '+$6.00 delivery', 'extracted': 6.0}
# 3      {'raw': '+$5.17 delivery', 'extracted': 5.17}
# 4      {'raw': '+$5.62 delivery', 'extracted': 5.62}
# ..                                               ...
# 235     {'raw': '+$5.00 delivery', 'extracted': 5.0}
# 236    {'raw': '+$8.99 delivery', 'extracted': 8.99}
# 237     {'raw': '+$6.00 delivery', 'extracted': 6.0}
# 238                                    Free delivery
# 239                                    Free delivery
#
#                      location             returns   buying_format  \
# 0           Located in Canada  Sell one like this      buy_it_now
# 1    Located in United States  Sell one like this  accepts_offers
# 2    Located in United States  Sell one like this  accepts_offers
# 3    Located in United States  Sell one like this  accepts_offers
# 4    Located in United States  Sell one like this  accepts_offers
# ..                        ...                 ...             ...
# 235  Located in United States  Sell one like this  accepts_offers
# 236  Located in United States  Sell one like this      buy_it_now
# 237  Located in United States  Sell one like this      buy_it_now
# 238  Located in United States  Sell one like this  accepts_offers
# 239  Located in United States  Sell one like this  accepts_offers
#
#     buying_format_text                                          thumbnail  \
# 0           Buy It Now  https://i.ebayimg.com/images/g/hQcAAeSwmIZp1ZP...
# 1        or Best Offer  https://i.ebayimg.com/images/g/nrsAAeSw16pp-95...
# 2        or Best Offer  https://i.ebayimg.com/images/g/c3AAAeSw7pFp~1~...
# 3        or Best Offer  https://i.ebayimg.com/images/g/rZcAAeSwTpVp99k...
# 4        or Best Offer  https://i.ebayimg.com/images/g/pDsAAeSwhIJp~Z2...
# ..                 ...                                                ...
# 235      or Best Offer  https://i.ebayimg.com/images/g/4AYAAOSwLSpkf1N...
# 236         Buy It Now  https://i.ebayimg.com/images/g/0a8AAeSwmDRpm2v...
# 237         Buy It Now  https://i.ebayimg.com/images/g/hjwAAeSw7YVpoOF...
# 238      or Best Offer  https://i.ebayimg.com/images/g/PcYAAeSwT3BpnjL...
# 239      or Best Offer  https://i.ebayimg.com/images/g/OegAAeSwekRpm3X...
#
#                                                 seller     sold_date  \
# 0    {'username': 'monkeymansports', 'reviews': 110...   May 5, 2026
# 1    {'username': 'avcards16', 'reviews': 20, 'posi...   May 9, 2026
# 2    {'username': 'braydesega_0', 'reviews': 511, '...   May 9, 2026
# 3    {'username': 'aasche43', 'reviews': 5, 'positi...   May 8, 2026
# 4    {'username': 'tokyoprizmcollections', 'reviews...   May 8, 2026
# ..                                                 ...           ...
# 235  {'username': 'wingsunion', 'reviews': 1100, 'p...  Feb 26, 2026
# 236  {'username': 'curly0597', 'reviews': 2700, 'po...  Feb 26, 2026
# 237  {'username': 'swank_piece', 'reviews': 1900, '...  Feb 26, 2026
# 238  {'username': 'barndog22', 'reviews': 4400, 'po...  Feb 26, 2026
# 239  {'username': 'stasp10', 'reviews': 475, 'posit...  Feb 26, 2026
#
#             epid  rating  reviews                extensions old_price subtitle
# 0            NaN     NaN      NaN                       NaN       NaN      NaN
# 1     9056541523     NaN      NaN                       NaN       NaN      NaN
# 2    21056483551     5.0      1.0  [Authenticity Guarantee]       NaN      NaN
# 3     8056494284     5.0      5.0                       NaN       NaN      NaN
# 4     4077830022     NaN      NaN                       NaN       NaN      NaN
# ..           ...     ...      ...                       ...       ...      ...
# 235  11089766272     NaN      NaN                       NaN       NaN      NaN
# 236   8056494284     5.0      5.0  [Authenticity Guarantee]       NaN      NaN
# 237   8056494284     5.0      5.0  [Authenticity Guarantee]       NaN      NaN
# 238   8056494284     5.0      5.0  [Authenticity Guarantee]       NaN      NaN
# 239   9056540715     NaN      NaN  [Authenticity Guarantee]       NaN      NaN
#
# [240 rows x 20 columns]

# %%
# Prints part of the dataframe to see what it looks like
dfE
# Out:
#                                                 title  \
# 0   Jack Hughes Signed 2019/20 Upper Deck Young Gu...
# 1   2019-20 Upper Deck - Young Guns Jack Hughes #2...
# 2   2019 Upper Deck #250 Jack Hughes & Quinn Hughe...
# 3   CONNOR MCDAVID 2015-16 Upper Deck Young Guns U...
# 4   2019-20 Upper Deck - Young Guns Jack Hughes #2...
# 5   2019-20 Upper Deck JACK HUGHES YOUNG GUNS ROOK...
# 6   2019-20 Upper Deck Jack Hughes #201 Clear Cut ...
# 13          NaN  New (Other)     NaN      NaN
# 14          NaN  New (Other)     NaN      NaN
# 15   7056545101  New (Other)     NaN      NaN
# 16   7056545101  New (Other)     NaN      NaN
# 17  18089760665    Pre-Owned     NaN      NaN
# 18   7056545101  New (Other)     NaN      NaN
# 19          NaN  New (Other)     NaN      NaN
# 20   8056494284  New (Other)     5.0      5.0
# 21  13089782671  New (Other)     NaN      NaN
# 22   3056541229  New (Other)     NaN      NaN
# 23   8056494284  New (Other)     5.0      5.0
# 24   8056494284  New (Other)     5.0      5.0
# 25   8056494284  New (Other)     5.0      5.0
# 26  28056495808  New (Other)     NaN      NaN
# 27          NaN  New (Other)     NaN      NaN
# 28   8056494284  New (Other)     5.0      5.0
# 29   8056494284  New (Other)     5.0      5.0
# 30   9056540715  New (Other)     NaN      NaN
#
#                                          price  \
# 0      {'raw': '$799.99', 'extracted': 799.99}
# 1      {'raw': '$349.99', 'extracted': 349.99}
# 2    {'raw': '$2,800.00', 'extracted': 2800.0}
# 3   {'raw': '$1,645.09', 'extracted': 1645.09}
# 4       {'raw': '$525.00', 'extracted': 525.0}
# 5       {'raw': '$750.00', 'extracted': 750.0}
# 6   {'raw': '$1,199.86', 'extracted': 1199.86}
# 7      {'raw': '$319.99', 'extracted': 319.99}
# 8       {'raw': '$428.00', 'extracted': 428.0}
# 9    {'raw': '$1,999.00', 'extracted': 1999.0}
# 10  {'raw': '$1,399.99', 'extracted': 1399.99}
# 11      {'raw': '$400.00', 'extracted': 400.0}
# 12      {'raw': '$750.00', 'extracted': 750.0}
# 13     {'raw': '$329.02', 'extracted': 329.02}
# 14     {'raw': '$599.95', 'extracted': 599.95}
# 15      {'raw': '$359.00', 'extracted': 359.0}
# 16      {'raw': '$389.00', 'extracted': 389.0}
# 17     {'raw': '$596.99', 'extracted': 596.99}
# 18      {'raw': '$449.00', 'extracted': 449.0}
# 19   {'raw': '$1,678.00', 'extracted': 1678.0}
# 20  {'raw': '$1,799.99', 'extracted': 1799.99}
# 21      {'raw': '$686.00', 'extracted': 686.0}
# 22      {'raw': '$450.00', 'extracted': 450.0}
# 23      {'raw': '$324.00', 'extracted': 324.0}
# 24     {'raw': '$999.99', 'extracted': 999.99}
# 25      {'raw': '$325.00', 'extracted': 325.0}
# 26  {'raw': '$1,999.99', 'extracted': 1999.99}
# 27     {'raw': '$349.99', 'extracted': 349.99}
# 28      {'raw': '$318.60', 'extracted': 318.6}
# 29      {'raw': '$315.00', 'extracted': 315.0}
# 30   {'raw': '$1,400.00', 'extracted': 1400.0}
#
#                                             old_price  \
# 0   {'raw': '$999.99', 'extracted': 999.99, 'disco...
# 1                                                 NaN
# 2   {'raw': '$4,000.00', 'extracted': 4000.0, 'dis...
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
#
#                                            shipping                  location  \
# 0     {'raw': '+$5.89 delivery', 'extracted': 5.89}  Located in United States
# 1     {'raw': '+$5.72 delivery', 'extracted': 5.72}  Located in United States
# 2      {'raw': '+$6.50 delivery', 'extracted': 6.5}  Located in United States
# 3   {'raw': '+$56.96 delivery', 'extracted': 56.96}         Located in Canada
# 4     {'raw': '+$8.95 delivery', 'extracted': 8.95}  Located in United States
# 5     {'raw': '+$5.97 delivery', 'extracted': 5.97}  Located in United States
# 6                                     Free delivery  Located in United States
# 7      {'raw': '+$6.00 delivery', 'extracted': 6.0}  Located in United States
# 8     {'raw': '+$4.99 delivery', 'extracted': 4.99}  Located in United States
# 9     {'raw': '+$5.97 delivery', 'extracted': 5.97}  Located in United States
# 10     {'raw': '+$4.50 delivery', 'extracted': 4.5}  Located in United States
# 11   {'raw': '+$10.00 delivery', 'extracted': 10.0}  Located in United States
# 12                                    Free delivery  Located in United States
# 13  {'raw': '+$14.62 delivery', 'extracted': 14.62}         Located in Canada
# 14    {'raw': '+$5.95 delivery', 'extracted': 5.95}         Located in Canada
# 15    {'raw': '+$5.49 delivery', 'extracted': 5.49}  Located in United States
# 16    {'raw': '+$5.49 delivery', 'extracted': 5.49}  Located in United States
# 17    {'raw': '+$8.75 delivery', 'extracted': 8.75}  Located in United States
# 18    {'raw': '+$5.49 delivery', 'extracted': 5.49}  Located in United States
# 19  {'raw': '+$18.24 delivery', 'extracted': 18.24}         Located in Canada
# 20    {'raw': '+$4.99 delivery', 'extracted': 4.99}  Located in United States
# 21    {'raw': '+$6.07 delivery', 'extracted': 6.07}  Located in United States
# 22    {'raw': '+$6.49 delivery', 'extracted': 6.49}  Located in United States
# 23    {'raw': '+$5.24 delivery', 'extracted': 5.24}  Located in United States
# 24                                    Free delivery  Located in United States
# 25    {'raw': '+$4.47 delivery', 'extracted': 4.47}  Located in United States
# 26   {'raw': '+$50.00 delivery', 'extracted': 50.0}      Located in Hong Kong
# 27    {'raw': '+$9.45 delivery', 'extracted': 9.45}  Located in United States
# 28     {'raw': '+$6.00 delivery', 'extracted': 6.0}  Located in United States
# 29                                    Free delivery  Located in United States
# 30                                    Free delivery  Located in United States
#
#                returns   buying_format buying_format_text  \
# 0   Sell one like this  accepts_offers      or Best Offer
# 1   Sell one like this  accepts_offers      or Best Offer
# 2   Sell one like this  accepts_offers      or Best Offer
# 3   Sell one like this  accepts_offers      or Best Offer
# 4   Sell one like this      buy_it_now         Buy It Now
# 5   Sell one like this  accepts_offers      or Best Offer
# 6   Sell one like this      buy_it_now         Buy It Now
# 7   Sell one like this      buy_it_now         Buy It Now
# 8   Sell one like this      buy_it_now         Buy It Now
# 9   Sell one like this  accepts_offers      or Best Offer
# 10  Sell one like this  accepts_offers      or Best Offer
# 11  Sell one like this      buy_it_now         Buy It Now
# 12  Sell one like this  accepts_offers      or Best Offer
# 13  Sell one like this  accepts_offers      or Best Offer
# 14  Sell one like this  accepts_offers      or Best Offer
# 15  Sell one like this  accepts_offers      or Best Offer
# 16  Sell one like this  accepts_offers      or Best Offer
# 17  Sell one like this  accepts_offers      or Best Offer
# 18  Sell one like this  accepts_offers      or Best Offer
# 19  Sell one like this  accepts_offers      or Best Offer
# 20  Sell one like this  accepts_offers      or Best Offer
# 21  Sell one like this  accepts_offers      or Best Offer
# 22  Sell one like this  accepts_offers      or Best Offer
# 23  Sell one like this  accepts_offers      or Best Offer
# 24  Sell one like this  accepts_offers      or Best Offer
# 6   {'username': 'tmhunh', 'reviews': 14300, 'posi...  Apr 23, 2026
# 7   {'username': 'swank_piece', 'reviews': 1900, '...  Apr 22, 2026
# 8   {'username': 'comc_consignment', 'reviews': 14...  Apr 19, 2026
# 9   {'username': 'concol133', 'reviews': 204, 'pos...  Apr 18, 2026
# 10  {'username': 'bgn_cards', 'reviews': 5200, 'po...  Apr 17, 2026
# 11  {'username': '47marciano0hwt', 'reviews': 1200...  Apr 14, 2026
# 12  {'username': 'thrive_collectibles_and_goods', ...   Apr 6, 2026
# 13  {'username': 'ace_cards87', 'reviews': 613, 'p...  Feb 22, 2026
# 14  {'username': 'wiser', 'reviews': 25200, 'posit...   Apr 5, 2026
# 15  {'username': 'sportcardculture', 'reviews': 33...   Apr 4, 2026
# 16  {'username': 'sportcardculture', 'reviews': 33...  Mar 25, 2026
# 17  {'username': 'jorbac-92', 'reviews': 1700, 'po...  Mar 23, 2026
# 18  {'username': 'sportcardculture', 'reviews': 33...  Mar 16, 2026
# 19  {'username': 'collectionhobbys', 'reviews': 66...  Mar 16, 2026
# 20  {'username': 'dogwoodcollectiblesnyonig', 'rev...  Feb 23, 2026
# 21  {'username': 'jthoffman7', 'reviews': 402, 'po...  Mar 14, 2026
# 22  {'username': 'ckodavis8', 'reviews': 2100, 'po...  Mar 11, 2026
# 23  {'username': 'escorj', 'reviews': 1600, 'posit...   Mar 9, 2026
# 24  {'username': 'bluechipautographs', 'reviews': ...   Mar 6, 2026
# 25  {'username': 'kwsm1t12', 'reviews': 753, 'posi...  Feb 28, 2026
# 26  {'username': 'sage1227', 'reviews': 529, 'posi...  Feb 27, 2026
# 27  {'username': 'reddie7', 'reviews': 3000, 'posi...  Feb 26, 2026
# 28  {'username': 'swank_piece', 'reviews': 1900, '...  Feb 26, 2026
# 29  {'username': 'barndog22', 'reviews': 4400, 'po...  Feb 26, 2026
# 30  {'username': 'stasp10', 'reviews': 475, 'posit...  Feb 26, 2026
#
#                   extensions  \
# 0                        NaN
# 1   [Authenticity Guarantee]
# 2   [Authenticity Guarantee]
# 3                        NaN
# 4   [Authenticity Guarantee]
# 5   [Authenticity Guarantee]
# 6   [Authenticity Guarantee]
# 7   [Authenticity Guarantee]
# 8   [Authenticity Guarantee]
# 9   [Authenticity Guarantee]
# 10  [Authenticity Guarantee]
# 11  [Authenticity Guarantee]
# 12  [Authenticity Guarantee]
# 13                       NaN
# 14                       NaN
# 15  [Authenticity Guarantee]
# 16  [Authenticity Guarantee]
# 17                       NaN
# 18  [Authenticity Guarantee]
# 19                       NaN
# 20  [Authenticity Guarantee]
# 21  [Authenticity Guarantee]
# 22  [Authenticity Guarantee]
# 23  [Authenticity Guarantee]
# 24  [Authenticity Guarantee]
# 25  [Authenticity Guarantee]
# 26                       NaN
# 27  [Authenticity Guarantee]
# 28  [Authenticity Guarantee]
# 29  [Authenticity Guarantee]
# 30  [Authenticity Guarantee]
#
#                                              subtitle
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8   Fulfilled by COMC - World’s largest consignmen...
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN

# %% [markdown]
# Obviously, this is still quite unclean, so we must fix this.

# %% [markdown]
# # Cleaning Some Variables

# %%
# ONLY RUN THIS ONCE PER API USAGE (extracts PRICE and SHIPPING with TITLE from the unclean data)
df1['price'] = df1['price'].apply(lambda x: x.get('extracted') if isinstance(x, dict) else None)
df1['shipping'] = df1['shipping'].apply(lambda x: x.get('extracted') if isinstance(x, dict) else 0)
df1['old_price'] = df1['old_price'].apply(lambda x: x.get('extracted') if isinstance(x, dict) else None)

# Prints a few lines to ensure the cleaning was done correctly 
print(df1[['title', 'price', 'shipping']].head())
df1.to_csv("df1_output.csv", index=False)

# ONLY RUN THIS ONCE PER API USAGE (extracts PRICE and SHIPPING with TITLE from the unclean data)
dfE['price'] = dfE['price'].apply(lambda x: x.get('extracted') if isinstance(x, dict) else None)
dfE['shipping'] = dfE['shipping'].apply(lambda x: x.get('extracted') if isinstance(x, dict) else 0)
dfE['old_price'] = dfE['old_price'].apply(lambda x: x.get('extracted') if isinstance(x, dict) else None)

# Prints a few lines to ensure the cleaning was done correctly 
print(dfE[['title', 'price', 'shipping']].head())
dfE.to_csv("dfE_output.csv", index=False)
# Out:
#                                                title   price  shipping
# 0  2019-20 Series 1 - Jack Hughes Rookie RC YOUNG...  204.69     13.75
# 1  2019 Jack Hughes O-Pee-Chee OPC Update Retro M...  150.00      5.72
# 2     2019 Upper Deck Quinn Hughes Young Guns PSA 10  275.00      6.00
# 3  2019-20 Upper Deck - Young Guns Jack Hughes #2...  130.00      5.17
# 4  2024 Upper Deck Jack Hughes Young Guns Renewed...  110.00      5.62
#                                                title    price  shipping
# 0  Jack Hughes Signed 2019/20 Upper Deck Young Gu...   799.99      5.89
# 1  2019-20 Upper Deck - Young Guns Jack Hughes #2...   349.99      5.72
# 2  2019 Upper Deck #250 Jack Hughes & Quinn Hughe...  2800.00      6.50
# 3  CONNOR MCDAVID 2015-16 Upper Deck Young Guns U...  1645.09     56.96
# 4  2019-20 Upper Deck - Young Guns Jack Hughes #2...   525.00      8.95

# %%
# Reads csv
df1 = pd.read_csv("df1_output.csv")

# Convert sold_date to datetime
df1['sold_date'] = pd.to_datetime(df1['sold_date'], format='mixed')

# Create dummy for sales after Feb 22 2026
df1['after_feb22'] = df1['sold_date'].apply(lambda x: 1 if x > pd.Timestamp('2026-02-22') else 0)

# Prints out first few lines of csv to ensure cleaning was done correctly
print(df1[['title', 'price', 'sold_date', 'after_feb22']].head())

#Saves to csv
df1.to_csv("df1_output.csv", index=False)
# Out:
#                                                title   price  sold_date  \
# 0  2019-20 Series 1 - Jack Hughes Rookie RC YOUNG...  204.69 2026-05-05
# 1  2019 Jack Hughes O-Pee-Chee OPC Update Retro M...  150.00 2026-05-09
# 2     2019 Upper Deck Quinn Hughes Young Guns PSA 10  275.00 2026-05-09
# 3  2019-20 Upper Deck - Young Guns Jack Hughes #2...  130.00 2026-05-08
# 4  2024 Upper Deck Jack Hughes Young Guns Renewed...  110.00 2026-05-08
#
#    after_feb22
# 0            1
# 1            1
# 2            1
# 3            1
# 4            1

# %%
# Reads csv
df1 = pd.read_csv("df1_output.csv")

# Eliminates ratings that do not exist
df1['rating'] = df1['rating'].fillna('')
df1.to_csv("df1_output.csv", index=False)

# Prints few lines of csv to ensure cleaning was done correctly
print(df1['rating'].head(10))
# Out:
# 0
# 1
# 2    5.0
# 3    5.0
# 4
# 5
# 6
# 7
# 8    5.0
# 9    5.0
# Name: rating, dtype: object

# %%
# Reads csv
dfE = pd.read_csv("dfE_output.csv")

# Eliminates ratings that do not exist
dfE['rating'] = dfE['rating'].fillna('')
dfE.to_csv("dfE_output.csv", index=False)

# Prints few lines of csv to ensure that cleaning was done correctly
print(dfE['rating'].head(10))
# Out:
# 0    5.0
# 1    5.0
# 2
# 3
# 4
# 5
# 6
# 7    5.0
# 8
# 9
# Name: rating, dtype: object

# %%
# Drops unneeded columns
df1 = df1.drop(columns=['link', 'serpapi_link', 'product_id', 'returns', 'buying_format', 'buying_format_text', 'thumbnail', 'seller', 'extensions', 'epid', 'reviews', 'old_price', 'subtitle'])

# %%
# 1 = Located in United States, 0 = everywhere else
df1['us_seller'] = (df1['location'] == 'Located in United States').astype(int)

# %%
# Logs price and shipping for future regressions
df1['Log of Price'] = np.log(df1['price'])
df1['Log of Shipping'] = np.log(df1['shipping'] + 1)  # +1 to handle free shipping

# %%
# Renames columns
df1.columns = ['Title', 'Condition', 'Price', 'Shipping', 'Location', 'Sold Date', 'Rating', 'Sold After 2/22/26', 'US Seller', 'Log of Price', 'Log of Shipping',]  # must match total number of columns

# %%
# Prints dataframe
df1
# Out:
#                                                  Title    Condition    Price  \
# 0    2019-20 Series 1 - Jack Hughes Rookie RC YOUNG...  New (Other)   204.69
# 1    2019 Jack Hughes O-Pee-Chee OPC Update Retro M...  New (Other)   150.00
# 2       2019 Upper Deck Quinn Hughes Young Guns PSA 10  New (Other)   275.00
# 3    2019-20 Upper Deck - Young Guns Jack Hughes #2...  New (Other)   130.00
# 4    2024 Upper Deck Jack Hughes Young Guns Renewed...  New (Other)   110.00
# ..                                                 ...          ...      ...
# 235  2019-20 UD Shooting Stars Jack Hughes ROOKIE #...  New (Other)    75.00
# 236  JACK HUGHES 2019-20 Upper Deck Young Guns RC #...  New (Other)   299.99
# 237  2019-20 Upper Deck Jack Hughes Young Guns Rook...  New (Other)   318.60
# 238  2019-20 Upper Deck - Young Guns Jack Hughes #2...  New (Other)   315.00
# 239  🥇🔥Jack Hughes-2019-20 Upper Deck - Silver Foil...  New (Other)  1400.00
#
#      Shipping                  Location   Sold Date Rating  \
# 0       13.75         Located in Canada  2026-05-05
# 1        5.72  Located in United States  2026-05-09
# 2        6.00  Located in United States  2026-05-09    5.0
# 3        5.17  Located in United States  2026-05-08    5.0
# 4        5.62  Located in United States  2026-05-08
# ..        ...                       ...         ...    ...
# 235      5.00  Located in United States  2026-02-26
# 236      8.99  Located in United States  2026-02-26    5.0
# 237      6.00  Located in United States  2026-02-26    5.0
# 238      0.00  Located in United States  2026-02-26    5.0
# 239      0.00  Located in United States  2026-02-26
#
#      Sold After 2/22/26  US Seller  Log of Price  Log of Shipping
# 0                     1          0      5.321497         2.691243
# 1                     1          1      5.010635         1.905088
# 2                     1          1      5.616771         1.945910
# 3                     1          1      4.867534         1.819699
# 4                     1          1      4.700480         1.890095
# ..                  ...        ...           ...              ...
# 235                   1          1      4.317488         1.791759
# 236                   1          1      5.703749         2.301585
# 237                   1          1      5.763936         1.945910
# 238                   1          1      5.752573         0.000000
# 239                   1          1      7.244228         0.000000
#
# [240 rows x 11 columns]

# %%
# Drops unneeded columns
dfE = dfE.drop(columns=['link', 'serpapi_link', 'product_id', 'returns', 'buying_format', 'buying_format_text', 'thumbnail', 'seller', 'extensions', 'epid', 'reviews', 'old_price', 'subtitle'])

# %%
# 1 = Located in United States, 0 = everywhere else
dfE['us_seller'] = (dfE['location'] == 'Located in United States').astype(int)

# %%
#Logs price and shipping for future regressions
dfE['log_price'] = np.log(dfE['price'])
dfE['Log of Shipping'] = np.log(dfE['shipping'] + 1)  # +1 to handle free shipping

# %%
# Renames columns
dfE.columns = ['Title', 'Condition', 'Rating', 'Price', 'Shipping', 'Location', 'Sold Date', 'US Seller', 'Log of Price', 'Log of Shipping']  # must match total number of columns

# %%
#Prints dataframe
dfE
# Out:
#                                                 Title    Condition Rating  \
# 0   Jack Hughes Signed 2019/20 Upper Deck Young Gu...    Pre-Owned    5.0
# 1   2019-20 Upper Deck - Young Guns Jack Hughes #2...  New (Other)    5.0
# 2   2019 Upper Deck #250 Jack Hughes & Quinn Hughe...  New (Other)
# 3   CONNOR MCDAVID 2015-16 Upper Deck Young Guns U...  New (Other)
# 4   2019-20 Upper Deck - Young Guns Jack Hughes #2...  New (Other)
# 5   2019-20 Upper Deck JACK HUGHES YOUNG GUNS ROOK...  New (Other)
# 6   2019-20 Upper Deck Jack Hughes #201 Clear Cut ...  New (Other)
# 7   2019-20 Upper Deck Quinn Hughes Young Guns Roo...  New (Other)    5.0
# 8   2019-20 Upper Deck Speckled Rainbow Foil Jack ...  New (Other)
# 9   2019-20 Jack Hughes UD Young Guns Speckled Rai...  New (Other)
# 10  2019-20 Upper Deck Jack Hughes Young Guns Rook...  New (Other)
# 11  2019-20 Upper Deck - Young Guns Jack Hughes #2...  New (Other)    5.0
# 12  2019-20 Upper Deck Jack Hughes, Quinn Hughes Y...  New (Other)
# 13     2019-20 Series 1 Jack Hughes Young Guns Psa 10  New (Other)
# 14  2019-20 UD Series 1 Jack, Quinn Hughes YG Chec...  New (Other)
# 15  2019 Jack Hughes RC PSA 10 -more rare Young Gu...  New (Other)
# 16  2019 Jack Hughes RC PSA 10 -more RARE Young Gu...  New (Other)
# 17  2019-20 Upper Deck Signed Jack Hughes Young Gu...    Pre-Owned
# 18  2019 Jack Hughes RC PSA 10 -more rare than You...  New (Other)
# 19  JACK HUGHES 2019-20 Upper Deck YOUNG GUNS Clea...  New (Other)
# 20  2019 Jack Hughes Young Guns PSA 10 AUTO 10 Roo...  New (Other)    5.0
# 21  2024-2025 Upper Deck Jack Hughes Retro Young G...  New (Other)
# 22  2019 Upper Deck Jack Hughes Young Guns Speckle...  New (Other)
# 23  ✅ 2019-20 Upper Deck Young Guns JACK HUGHES PS...  New (Other)    5.0
# 24  Jack Hughes 2019-20 Upper Deck #201 UD Signed ...  New (Other)    5.0
# 25  2019-20 Upper Deck Young Guns #201 Jack Hughes...  New (Other)    5.0
# 24      6.907745         0.000000
# 25      5.783825         1.699279
# 26      7.600897         3.931826
# 27      5.857905         2.346602
# 28      5.763936         1.945910
# 29      5.752573         0.000000
# 30      7.244228         0.000000

# %%
# Saves csvs

df1.to_csv("df1_output.csv", index=False)
dfE.to_csv("dfE_output.csv", index=False)

# %% [markdown]
# ### Interestingly enough, all of the most expensive cards were scored after the "Golden Goal." The data looks quite clean now and ready for analysis.

# %% [markdown]
# # Part 3: Graphs

# %% [markdown]
# ## Graphs: Price vs. Shipping and Price Histogram

# %% [markdown]
# This may not seem very interesting at first, but I want to figure out if higher prices for cards lead to higher shipping as an exercise in behavioral economics. If something is so expensive and one adds an extra fee on top of everything, will that really impact the willingness of a person to buy that product? I also want to see the distribution of how many cards were sold for at what prices.

# %%
# Load csv
dfE = pd.read_csv("dfE_output.csv")
dfE['Sold Date'] = pd.to_datetime(dfE['Sold Date'], format='mixed')
dfE_sorted = dfE.sort_values('Sold Date').reset_index(drop=True)

# Roling averages
dfE_sorted['price_rolling'] = dfE_sorted['Price'].rolling(window=7, min_periods=1).mean()
dfE_sorted['shipping_rolling'] = dfE_sorted['Shipping'].rolling(window=7, min_periods=1).mean()

# Calculates mean
avg_price = dfE_sorted['Price'].mean()

# Creates figure
fig, (ax1, ax3) = plt.subplots(2, 1, figsize=(12, 10))

# Price on left axis
ax1.plot(dfE_sorted['Sold Date'], dfE_sorted['price_rolling'],
         color='r', linewidth=2, label='Price (7-day avg)')
ax1.scatter(dfE_sorted['Sold Date'], dfE_sorted['Price'],
            color='r', alpha=0.2, s=15)
ax1.axhline(avg_price, color='r', linestyle=':', linewidth=1.5,
            alpha=0.7, label=f'Avg Price ${avg_price:.0f}')
ax1.set_xlabel('Date Sold')
ax1.set_ylabel('Sale Price (USD)', color='r', fontsize=12)
ax1.tick_params(axis='y', labelcolor='r')

# Shipping on right axis
ax2 = ax1.twinx()
ax2.plot(dfE_sorted['Sold Date'], dfE_sorted['shipping_rolling'],
         color='k', linewidth=2, label='Shipping (7-day avg)')
ax2.scatter(dfE_sorted['Sold Date'], dfE_sorted['Shipping'],
            color='k', alpha=0.2, s=15)
ax2.set_ylabel('Shipping Cost (USD)', color='k', fontsize=12)
ax2.tick_params(axis='y', labelcolor='k')

# Combined legend
lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines1 + lines2, labels1 + labels2, fontsize=11)

ax1.set_title('Expensive Jack Hughes Young Guns PSA 10 — Price vs Shipping Over Time & Price Histogram', fontsize=14, fontweight='bold')
ax1.grid(True, linestyle='--', alpha=0.5)
ax1.tick_params(axis='x', rotation=45)

# Histogram
# Log transform the price
ax3.hist(np.log(dfE_sorted['Price']), bins=20, color='r', edgecolor='white', alpha=0.7)
ax3.axvline(np.log(avg_price), color='k', linestyle=':', linewidth=1.5,
            label=f'Avg Price ${avg_price:.0f}')
ax3.set_xlabel('Log of Sale Price', fontsize=12)
ax3.set_ylabel('Number of Sales', fontsize=12)
ax3.legend(fontsize=11)
ax3.grid(True, linestyle='--', alpha=0.5)

# Creates output
plt.tight_layout()
plt.savefig('Graphs.jpg', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# Now that we have extracted the data, cleaned the data, and visualized it, it is time to run regressions with it.
